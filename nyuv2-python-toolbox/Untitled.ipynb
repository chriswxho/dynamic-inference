# %%
from test import test_labeled_dataset
from pathlib import Path
from nyuv2 import LabeledDataset

# %%
dataset = LabeledDataset(Path('dataset') / 'nyu_depth_v2_labeled.mat')

# %%
test_labeled_dataset(3)

# %%
import matplotlib.pyplot as plt
plt.imshow(dataset[3][1].T)

# %%
dataset[3][1].T.shape
# Out:
# (480, 640)

# %%
dataset[3][1][300,450]
# Out:
# 0.8114584

# %%
plt.imsave('image.jpg',dataset[3][0].T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d1da90e34348> in <module>
# ----> 1 plt.imsave('image.jpg',dataset[3][0].T)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in imsave(fname, arr, **kwargs)
#    2249 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2250 def imsave(fname, arr, **kwargs):
# -> 2251     return matplotlib.image.imsave(fname, arr, **kwargs)
#    2252
#    2253
#
# ~/.local/lib/python3.8/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1569             rgba = arr
#    1570         else:
# -> 1571             rgba = sm.to_rgba(arr, bytes=True)
#    1572         if pil_kwargs is None:
#    1573             pil_kwargs = {}
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
# ...

# %%
plt.imsave('image.jpg',np.moveaxis(dataset[0][0].T, 0, 2))
